# %% [markdown]
# # Digital inverter with OpenLane
#
# ```
# Copyright 2022 Google LLC.
# SPDX-License-Identifier: Apache-2.0
# ```
#
# Run a simple digital inverter design thru the [OpenLane](https://github.com/The-OpenROAD-Project/OpenLane/) GDS to RTL flow targeting the [open source SKY130 PDK](https://github.com/google/skywater-pdk/).

# %%
#@title Install dependencies {display-mode: "form"}
#@markdown - Click the ▷ button to setup the digital design environment based on [conda-eda](https://github.com/hdl/conda-eda).

openlane_version = 'latest' #@param {type:"string"}
open_pdks_version = 'latest' #@param {type:"string"}

if openlane_version == 'latest':
  openlane_version = ''
if open_pdks_version == 'latest':
  open_pdks_version = ''

import os
import pathlib

# !curl -Ls https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xj bin/micromamba
conda_prefix_path = pathlib.Path('conda-env')
CONDA_PREFIX = str(conda_prefix_path.resolve())
# !bin/micromamba create --yes --prefix $CONDA_PREFIX
# !echo 'python ==3.7*' >> {CONDA_PREFIX}/conda-meta/pinned
# !CI=0 bin/micromamba install --yes --prefix $CONDA_PREFIX \
                     --channel litex-hub \
                     --channel main \
                     openlane={openlane_version} \
                     open_pdks.sky130a={open_pdks_version}
# !python -m pip install gdstk gdstk
PATH = os.environ['PATH']
# %env CONDA_PREFIX={CONDA_PREFIX}
# %env PATH={CONDA_PREFIX}/bin:{PATH}
# Out:
#                                            __
#           __  ______ ___  ____ _____ ___  / /_  ____ _
#          / / / / __ `__ \/ __ `/ __ `__ \/ __ \/ __ `/
#         / /_/ / / / / / / /_/ / / / / / / /_/ / /_/ /
#        / .___/_/ /_/ /_/\__,_/_/ /_/ /_/_.___/\__,_/
#       /_/
#
# Empty environment created at prefix: /content/conda-env
#
#                                            __
#           __  ______ ___  ____ _____ ___  / /_  ____ _
#          / / / / __ `__ \/ __ `/ __ `__ \/ __ \/ __ `/
#         / /_/ / / / / / / /_/ / / / / / / /_/ / /_/ /
#        / .___/_/ /_/ /_/\__,_/_/ /_/ /_/_.___/\__,_/
#       /_/
#
#
# Pinned packages:
#   - python 3.7*
#
#
# Transaction
#
#   Prefix: /content/conda-env
#
#   Updating specs:
#
#    - openlane=*
#    - open_pdks.sky130a=*
#
#
#   Package                              Version  Build                 Channel                 Size
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   + _libgcc_mutex                          0.1  main                  main/linux-64            3kB
#   + _openmp_mutex                          5.1  1_gnu                 main/linux-64           21kB
#   + bzip2                                1.0.8  h7b6447c_0            main/linux-64          107kB
#   + ca-certificates                 2023.01.10  h06a4308_0            main/linux-64          130kB
#   + cairo                              1.14.12  h8948797_3            main/linux-64            1MB
#   + certifi                          2022.12.7  py37h06a4308_0        main/linux-64          155kB
#   + click                                8.0.4  py37h06a4308_0        main/linux-64          152kB
#   + dbus                               1.13.18  hb2f20db_0            main/linux-64          600kB
#   + expat                                2.4.9  h6a678d5_0            main/linux-64          192kB
#   + flit-core                            3.6.0  pyhd3eb1b0_0          main/noarch             43kB
#   + fmt                                  8.1.1  hd09550d_1            main/linux-64          182kB
#   + fontconfig                          2.13.0  h9420a91_0            main/linux-64          298kB
#   + freetype                            2.12.1  h4a9f257_0            main/linux-64          972kB
#   + gdbm                                  1.18  hd4cb3f1_4            main/linux-64          197kB
#   + glib                                2.69.1  he621ea3_2            main/linux-64            2MB
#   + gmp                                  6.2.1  h295c915_3            main/linux-64          822kB
#   + gst-plugins-base                    1.14.1  h6a678d5_1            main/linux-64            2MB
#   + gstreamer                           1.14.1  h5eee18b_1            main/linux-64            2MB
#   + icu                                   58.2  he6710b0_3            main/linux-64           24MB
#   + importlib-metadata                  4.11.3  py37h06a4308_0        main/linux-64           41kB
#   + jpeg                                    9e  h5eee18b_1            main/linux-64          281kB
#   + klayout                0.28.6_0_gc931a08ec  20230225_164303_py37  litex-hub/linux-64      26MB
#   + ld_impl_linux-64                      2.38  h1181459_1            main/linux-64          749kB
#   + libboost                            1.73.0  h28710b8_12           main/linux-64           22MB
#   + libffi                               3.4.2  h6a678d5_6            main/linux-64          138kB
#   + libgcc-ng                           11.2.0  h1234567_1            main/linux-64            9MB
#   + libgomp                             11.2.0  h1234567_1            main/linux-64          573kB
#   + libpng                              1.6.39  h5eee18b_0            main/linux-64          363kB
#   + libstdcxx-ng                        11.2.0  h1234567_1            main/linux-64            6MB
#   + libuuid                             1.41.5  h5eee18b_0            main/linux-64           29kB
#   + libxcb                                1.15  h7f8727e_0            main/linux-64          623kB
#   + libxml2                              2.9.9  20220706_155948       litex-hub/linux-64       1MB
#   + lz4-c                                1.9.4  h6a678d5_0            main/linux-64          164kB
#   + magic                   8.3.382_0_g1044878  20230225_164303       litex-hub/linux-64       5MB
#   + ncurses                                6.4  h6a678d5_0            main/linux-64            1MB
#   + netgen                  1.5.250_0_g178b172  20230225_164303       litex-hub/linux-64     806kB
#   + open_pdks.sky130a       1.0.402_1_g12df12e  20230225_164303       litex-hub/noarch       128MB
#   + openlane            2023.03.01_0_ge10820ec  20230225_164303       litex-hub/noarch        12MB
#   + openroad               2.0_7070_g0264023b6  20230225_164303       litex-hub/linux-64      24MB
#   + openssl                             1.1.1t  h7f8727e_0            main/linux-64            4MB
#   + pcre                                  8.45  h295c915_0            main/linux-64          263kB
#   + pip                                 22.3.1  py37h06a4308_0        main/linux-64            3MB
#   + pixman                              0.40.0  h7f8727e_1            main/linux-64          645kB
#   + python                              3.7.16  h7a1cb2a_0            main/linux-64           49MB
#   + pyyaml                                 6.0  py37h5eee18b_1        main/linux-64          184kB
#   + qt                                   5.9.7  h5867ecd_1            main/linux-64           90MB
#   + readline                               8.2  h5eee18b_0            main/linux-64          468kB
#   + ruby                                 3.1.2  h006b21b_1            main/linux-64            9MB
#   + setuptools                          65.6.3  py37h06a4308_0        main/linux-64            1MB
#   + spdlog                               1.9.2  hd09550d_0            main/linux-64          217kB
#   + sqlite                              3.41.1  h5eee18b_0            main/linux-64            2MB
#   + tcllib                  1_21_47_g6c321309d  20230225_164303       litex-hub/noarch         2MB
#   + tk                                  8.6.12  h1ccaba5_0            main/linux-64            3MB
#   + typing_extensions                    4.4.0  py37h06a4308_0        main/linux-64           46kB
#   + wheel                               0.38.4  py37h06a4308_0        main/linux-64           59kB
#   + xz                                  5.2.10  h5eee18b_1            main/linux-64          459kB
#   + yaml                                 0.2.5  h7b6447c_0            main/linux-64           89kB
#   + yosys                   0.27_13_gceef00c35  20230225_164303_py37  litex-hub/linux-64      11MB
#   + zipp                                3.11.0  py37h06a4308_0        main/linux-64           18kB
#   + zlib                                1.2.13  h5eee18b_0            main/linux-64          128kB
#   + zstd                                 1.5.2  ha4553b6_0            main/linux-64          827kB
#
#   Summary:
#
#   Install: 61 packages
#
#   Total download: 451MB
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
# Transaction starting
# Linking open_pdks.sky130a-1.0.402_1_g12df12e-20230225_164303
# Linking _libgcc_mutex-0.1-main
# Linking libstdcxx-ng-11.2.0-h1234567_1
# Linking ld_impl_linux-64-2.38-h1181459_1
# Linking ca-certificates-2023.01.10-h06a4308_0
# Linking libgomp-11.2.0-h1234567_1
# Linking _openmp_mutex-5.1-1_gnu
# Linking libgcc-ng-11.2.0-h1234567_1
# Linking libuuid-1.41.5-h5eee18b_0
# Linking lz4-c-1.9.4-h6a678d5_0
# Linking gmp-6.2.1-h295c915_3
# Linking bzip2-1.0.8-h7b6447c_0
# Linking yaml-0.2.5-h7b6447c_0
# Linking pixman-0.40.0-h7f8727e_1
# Linking libxcb-1.15-h7f8727e_0
# Linking jpeg-9e-h5eee18b_1
# Linking icu-58.2-he6710b0_3
# Linking expat-2.4.9-h6a678d5_0
# Linking xz-5.2.10-h5eee18b_1
# Linking openssl-1.1.1t-h7f8727e_0
# Linking ncurses-6.4-h6a678d5_0
# Linking pcre-8.45-h295c915_0
# Linking libffi-3.4.2-h6a678d5_6
# Linking fmt-8.1.1-hd09550d_1
# Linking zlib-1.2.13-h5eee18b_0
# Linking readline-8.2-h5eee18b_0
# Linking spdlog-1.9.2-hd09550d_0
# Linking zstd-1.5.2-ha4553b6_0
# Linking libpng-1.6.39-h5eee18b_0
# Linking glib-2.69.1-he621ea3_2
# Linking tk-8.6.12-h1ccaba5_0
# Linking gdbm-1.18-hd4cb3f1_4
# Linking sqlite-3.41.1-h5eee18b_0
# Linking libboost-1.73.0-h28710b8_12
# Linking freetype-2.12.1-h4a9f257_0
# Linking gstreamer-1.14.1-h5eee18b_1
# Linking dbus-1.13.18-hb2f20db_0
# Linking ruby-3.1.2-h006b21b_1
# Linking python-3.7.16-h7a1cb2a_0
# Linking wheel-0.38.4-py37h06a4308_0
# Linking gst-plugins-base-1.14.1-h6a678d5_1
# Linking certifi-2022.12.7-py37h06a4308_0
# Linking setuptools-65.6.3-py37h06a4308_0
# Linking pip-22.3.1-py37h06a4308_0
# Linking pyyaml-6.0-py37h5eee18b_1
# Linking zipp-3.11.0-py37h06a4308_0
# Linking libxml2-2.9.9-20220706_155948
# Linking netgen-1.5.250_0_g178b172-20230225_164303
# Linking yosys-0.27_13_gceef00c35-20230225_164303_py37
# Linking tcllib-1_21_47_g6c321309d-20230225_164303
# Linking flit-core-3.6.0-pyhd3eb1b0_0
# Linking fontconfig-2.13.0-h9420a91_0
# Linking typing_extensions-4.4.0-py37h06a4308_0
# Linking cairo-1.14.12-h8948797_3
# Linking qt-5.9.7-h5867ecd_1
# Linking importlib-metadata-4.11.3-py37h06a4308_0
# Linking click-8.0.4-py37h06a4308_0
# Linking magic-8.3.382_0_g1044878-20230225_164303
# Linking klayout-0.28.6_0_gc931a08ec-20230225_164303_py37
# Linking openroad-2.0_7070_g0264023b6-20230225_164303
# Linking openlane-2023.03.01_0_ge10820ec-20230225_164303
# Transaction finished
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gdstk
#   Downloading gdstk-0.9.37-cp39-cp39-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (841 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.5/841.5 KB 28.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from gdstk) (1.22.4)
# Installing collected packages: gdstk
# Successfully installed gdstk-0.9.37
# env: CONDA_PREFIX=/content/conda-env
# env: PATH=/content/conda-env/bin:/opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin

# %% [markdown]
# ## Write verilog

# %%
# %%writefile nand2.v
# module nand2(input wire in,input wire in2, output wire out);
#     assign out = ~(in&in2);
# endmodule
# Out:
# Overwriting nand2.v

# %% [markdown]
# ## Write configuration
#
# [Documentation](https://openlane.readthedocs.io/en/latest/reference/configuration.html)

# %%
# %%writefile config.json
# {
#     "DESIGN_NAME": "nand2",
#     "VERILOG_FILES": "dir::nand2.v",
#     "CLOCK_TREE_SYNTH": false,
#     "CLOCK_PORT": null,
#     "PL_RANDOM_GLB_PLACEMENT": true,
#     "FP_SIZING": "absolute",
#     "DIE_AREA": "0 0 34.5 57.12",
#     "PL_TARGET_DENSITY": 0.75,
#     "FP_PDN_AUTO_ADJUST": false,
#     "FP_PDN_VPITCH": 25,
#     "FP_PDN_HPITCH": 25,
#     "FP_PDN_VOFFSET": 5,
#     "FP_PDN_HOFFSET": 5,
#     "DIODE_INSERTION_STRATEGY": 3
# }
# Out:
# Overwriting config.json

# %% [markdown]
# ## Run OpenLane Flow
#
# [OpenLane](https://openlane.readthedocs.io/en/latest/) is an automated [RTL](https://en.wikipedia.org/wiki/Register-transfer_level) to [GDSII](https://en.wikipedia.org/wiki/GDSII) flow based on several components including [OpenROAD](https://theopenroadproject.org/), [Yosys](https://yosyshq.net/yosys/), [Magic](http://www.opencircuitdesign.com/magic/), [Netgen](http://opencircuitdesign.com/netgen/) and custom methodology scripts for design exploration and optimization targeting [open source PDKs](https://github.com/google/open-source-pdks).
#
# ![img](https://openlane.readthedocs.io/en/latest/_images/flow_v1.png)

# %%
# %env PDK=sky130A
# !flow.tcl -design .
# Out:
# env: PDK=sky130A
# OpenLane 2023.03.01_0_ge10820ec-conda
# All rights reserved. (c) 2020-2022 Efabless Corporation and contributors.
# Available under the Apache License, version 2.0. See the LICENSE file for more details.
#
# [INFO]: Using configuration in 'config.json'...
# [INFO]: PDK Root: /content/conda-env/share/pdk
# [INFO]: Process Design Kit: sky130A
# [INFO]: Standard Cell Library: sky130_fd_sc_hd
# [INFO]: Optimization Standard Cell Library: sky130_fd_sc_hd
# [INFO]: Run Directory: /content/runs/RUN_2023.03.20_23.37.25
# [INFO]: Preparing LEF files for the nom corner...
# [INFO]: Preparing LEF files for the min corner...
# [INFO]: Preparing LEF files for the max corner...
# [STEP 1]
# [INFO]: Running Synthesis (log: runs/RUN_2023.03.20_23.37.25/logs/synthesis/1-synthesis.log)...
# [STEP 2]
# [INFO]: Running Single-Corner Static Timing Analysis (log: runs/RUN_2023.03.20_23.37.25/logs/synthesis/2-sta.log)...
# [STEP 3]
# [INFO]: Running Initial Floorplanning (log: runs/RUN_2023.03.20_23.37.25/logs/floorplan/3-initial_fp.log)...
# [INFO]: Floorplanned with width 23.46 and height 35.36.
# [STEP 4]
# [INFO]: Running IO Placement...
# [STEP 5]
# [INFO]: Running Tap/Decap Insertion (log: runs/RUN_2023.03.20_23.37.25/logs/floorplan/5-tap.log)...
# [INFO]: Power planning with power {VPWR} and ground {VGND}...
# [STEP 6]
# [INFO]: Generating PDN (log: runs/RUN_2023.03.20_23.37.25/logs/floorplan/6-pdn.log)...
# [STEP 7]
# [INFO]: Performing Random Global Placement (log: runs/RUN_2023.03.20_23.37.25/logs/placement/7-global.log)...
# [STEP 8]
# [INFO]: Running Placement Resizer Design Optimizations (log: runs/RUN_2023.03.20_23.37.25/logs/placement/8-resizer.log)...
# [STEP 9]
# [INFO]: Running Detailed Placement (log: runs/RUN_2023.03.20_23.37.25/logs/placement/9-detailed.log)...
# [STEP 10]
# [INFO]: Running Placement Resizer Timing Optimizations (log: runs/RUN_2023.03.20_23.37.25/logs/cts/10-resizer.log)...
# [STEP 11]
# [INFO]: Running Global Routing Resizer Timing Optimizations (log: runs/RUN_2023.03.20_23.37.25/logs/routing/11-resizer.log)...
# [STEP 12]
# [INFO]: Running Detailed Placement (log: runs/RUN_2023.03.20_23.37.25/logs/routing/12-diode_legalization.log)...
# [STEP 13]
# [INFO]: Running Global Routing (log: runs/RUN_2023.03.20_23.37.25/logs/routing/13-global.log)...
# [INFO]: Starting OpenROAD Antenna Repair Iterations...
# [STEP 14]
# [INFO]: Writing Verilog (log: runs/RUN_2023.03.20_23.37.25/logs/routing/13-global_write_netlist.log)...
# [STEP 15]
# [INFO]: Running Fill Insertion (log: runs/RUN_2023.03.20_23.37.25/logs/routing/15-fill.log)...
# [STEP 16]
# [INFO]: Running Detailed Routing (log: runs/RUN_2023.03.20_23.37.25/logs/routing/16-detailed.log)...
# [INFO]: No DRC violations after detailed routing.
# [STEP 17]
# [INFO]: Checking Wire Lengths (log: runs/RUN_2023.03.20_23.37.25/logs/routing/17-wire_lengths.log)...
# [STEP 18]
# [INFO]: Running SPEF Extraction at the min process corner (log: runs/RUN_2023.03.20_23.37.25/logs/signoff/18-parasitics_extraction.min.log)...
# [STEP 19]
# [INFO]: Running Multi-Corner Static Timing Analysis at the min process corner (log: runs/RUN_2023.03.20_23.37.25/logs/signoff/19-rcx_mcsta.min.log)...
# [STEP 20]
# [INFO]: Running SPEF Extraction at the max process corner (log: runs/RUN_2023.03.20_23.37.25/logs/signoff/20-parasitics_extraction.max.log)...
# [STEP 21]
# [INFO]: Running Multi-Corner Static Timing Analysis at the max process corner (log: runs/RUN_2023.03.20_23.37.25/logs/signoff/21-rcx_mcsta.max.log)...
# [STEP 22]
# [INFO]: Running SPEF Extraction at the nom process corner (log: runs/RUN_2023.03.20_23.37.25/logs/signoff/22-parasitics_extraction.nom.log)...
# [STEP 23]
# [INFO]: Running Multi-Corner Static Timing Analysis at the nom process corner (log: runs/RUN_2023.03.20_23.37.25/logs/signoff/23-rcx_mcsta.nom.log)...
# [STEP 24]
# [INFO]: Running Single-Corner Static Timing Analysis at the nom process corner (log: runs/RUN_2023.03.20_23.37.25/logs/signoff/24-rcx_sta.log)...
# [STEP 25]
# [INFO]: Creating IR Drop Report (log: runs/RUN_2023.03.20_23.37.25/logs/signoff/25-irdrop.log)...
# [STEP 26]
# [INFO]: Running Magic to generate various views...
# [INFO]: Streaming out GDSII with Magic (log: runs/RUN_2023.03.20_23.37.25/logs/signoff/26-gdsii.log)...
# [INFO]: Generating MAGLEF views...
# [STEP 27]
# [INFO]: Streaming out GDSII with KLayout (log: runs/RUN_2023.03.20_23.37.25/logs/signoff/27-gdsii-klayout.log)...
# [STEP 28]
# [INFO]: Running XOR on the layouts using KLayout (log: runs/RUN_2023.03.20_23.37.25/logs/signoff/28-xor.log)...
# [INFO]: No XOR differences between KLayout and Magic gds.
# [STEP 29]
# [INFO]: Running Magic Spice Export from LEF (log: runs/RUN_2023.03.20_23.37.25/logs/signoff/29-spice.log)...
# [STEP 30]
# [INFO]: Writing Powered Verilog (logs: runs/RUN_2023.03.20_23.37.25/logs/signoff/30-write_powered_def.log, runs/RUN_2023.03.20_23.37.25/logs/signoff/30-write_powered_verilog.log)...
# [STEP 31]
# [INFO]: Writing Verilog (log: runs/RUN_2023.03.20_23.37.25/logs/signoff/30-write_powered_verilog.log)...
# [STEP 32]
# [INFO]: Running LVS (log: runs/RUN_2023.03.20_23.37.25/logs/signoff/32-lvs.lef.log)...
# [STEP 33]
# [INFO]: Running Magic DRC (log: runs/RUN_2023.03.20_23.37.25/logs/signoff/33-drc.log)...
# [INFO]: Converting Magic DRC database to various tool-readable formats...
# [INFO]: No DRC violations after GDS streaming out.
# [STEP 34]
# [INFO]: Running OpenROAD Antenna Rule Checker (log: runs/RUN_2023.03.20_23.37.25/logs/signoff/34-antenna.log)...
# [INFO]: Saving current set of views in 'runs/RUN_2023.03.20_23.37.25/results/final'...
# [INFO]: Saving runtime environment...
# [INFO]: Generating final set of reports...
# [INFO]: Created manufacturability report at 'runs/RUN_2023.03.20_23.37.25/reports/manufacturability.rpt'.
# [INFO]: Created metrics report at 'runs/RUN_2023.03.20_23.37.25/reports/metrics.csv'.
# [INFO]: There are no max slew, max fanout or max capacitance violations in the design at the typical corner.
# [INFO]: There are no hold violations in the design at the typical corner.
# [INFO]: There are no setup violations in the design at the typical corner.
# [SUCCESS]: Flow complete.

# %% [markdown]
# ## Display layout

# %%
import pathlib
import gdstk
import IPython.display

gdss = sorted(pathlib.Path('runs').glob('*/results/final/gds/*.gds'))
library = gdstk.read_gds(gdss[-1])
top_cells = library.top_level()
top_cells[0].write_svg('nand2.svg')
IPython.display.SVG('nand2.svg')

# %% [markdown]
# ## Metrics
#
# [Documentation](https://openlane.readthedocs.io/en/latest/reference/datapoint_definitions.html)

# %%
import pandas as pd
import pathlib

pd.options.display.max_rows = None
reports = sorted(pathlib.Path('runs').glob('*/reports/metrics.csv'))
df = pd.read_csv(reports[-1])
df.transpose()
# Out:
#                                                   0
# design                                     /content
# design_name                                   nand2
# config                      RUN_2023.03.20_23.37.25
# flow_status                          flow completed
# total_runtime                            0h0m31s0ms
# routed_runtime                           0h0m15s0ms
# (Cell/mm^2)/Core_Util                   1014.898713
# DIEAREA_mm^2                               0.001971
# CellPer_mm^2                             507.449357
# OpenDP_Util                                      -1
# Peak_Memory_Usage_MB                         470.65
# cell_count                                        1
# tritonRoute_violations                            0
# Short_violations                                  0
# MetSpc_violations                                 0
# OffGrid_violations                                0
# MinHole_violations                                0
# Other_violations                                  0
# Magic_violations                                  0
# antenna_violations                                0
# lvs_total_errors                                  0
# cvc_total_errors                                 -1
# klayout_violations                               -1
# wire_length                                      99
# vias                                             19
# wns                                             0.0
# pl_wns                                           -1
# optimized_wns                                   0.0
# fastroute_wns                                   0.0
# spef_wns                                        0.0
# tns                                             0.0
# pl_tns                                           -1
# optimized_tns                                   0.0
# fastroute_tns                                   0.0
# spef_tns                                        0.0
# HPWL                                             -1
# routing_layer1_pct                              0.0
# routing_layer2_pct                             1.25
# routing_layer3_pct                             1.83
# routing_layer4_pct                              0.0
# routing_layer5_pct                              0.0
# routing_layer6_pct                              0.0
# wires_count                                       3
# wire_bits                                         3
# public_wires_count                                3
# public_wire_bits                                  3
# memories_count                                    0
# memory_bits                                       0
# processes_count                                   0
# cells_pre_abc                                     1
# AND                                               0
# DFF                                               0
# NAND                                              1
# NOR                                               0
# OR                                                0
# XOR                                               0
# XNOR                                              0
# MUX                                               0
# inputs                                            2
# outputs                                           1
# level                                             1
# EndCaps                                          26
# TapCells                                          7
# Diodes                                            0
# Total_Physical_Cells                             33
# CoreArea_um^2                              829.5456
# power_slowest_internal_uW                        -1
# power_slowest_switching_uW                       -1
# power_slowest_leakage_uW                         -1
# power_typical_internal_uW                        -1
# power_typical_switching_uW                       -1
# power_typical_leakage_uW                         -1
# power_fastest_internal_uW                        -1
# power_fastest_switching_uW                       -1
# power_fastest_leakage_uW                         -1
# critical_path_ns                               0.36
# suggested_clock_period                         10.0
# suggested_clock_frequency                     100.0
# CLOCK_PERIOD                                   10.0
# SYNTH_STRATEGY                                    3
# SYNTH_MAX_FANOUT                                  1
# FP_CORE_UTIL                                     50
# FP_ASPECT_RATIO                                  25
# FP_PDN_VPITCH                                    25
# FP_PDN_HPITCH                                   0.3
# PL_TARGET_DENSITY                              0.75
# GRT_ADJUSTMENT                      sky130_fd_sc_hd
# STD_CELL_LIBRARY                                 10
# DIODE_INSERTION_STRATEGY                     AREA 0
